# %%
#import dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import scipy.stats as st
from scipy.stats import linregress
from scipy import stats
import random

# %% [markdown]
# ### **Is there a relationship between anxiety and the motivation for gaming?** - Ashley
#
# #### Hypothesis:
# - If there is a relationship between anxiety and the motivation for gaming, then playing to have fun should result in a significantly different GAD-7 score compared to playing to win.

# %%
#reference file path
data = Path("../data_cleanup/Gaming.csv")

#import data into dataframe
oggame_df = pd.read_csv(data, encoding="UTF-8")

oggame_df.head()
# Out:
#    Unnamed: 0  Entry  Gender  Age Residence Birthplace  \
# 0           0      1    Male   25       USA        USA
# 1           1      2    Male   41       USA        USA
# 2           2      3  Female   32       DEU        DEU
# 3           3      4    Male   28       USA        USA
# 4           4      5    Male   19       KOR        USA
#
#                         Work                               Degree    Game  \
# 0  Unemployed / between jobs             Bachelor (or equivalent)  Skyrim
# 1  Unemployed / between jobs             Bachelor (or equivalent)   Other
# 2                   Employed             Bachelor (or equivalent)   Other
# 3                   Employed             Bachelor (or equivalent)   Other
# 4                   Employed  High school diploma (or equivalent)   Other
#
#    Hours per Week  ... SPIN9 SPIN10  SPIN11  SPIN12  SPIN13  SPIN14  SPIN15  \
# 0              15  ...     0      0       0       0       0       1       0
# 1               8  ...     4      0       3       0       1       3       3
# 2               0  ...     0      1       1       3       0       2       4
# 3              20  ...     0      0       1       3       0       0       1
# 4              20  ...     2      0       1       0       0       0       0
#
#    SPIN16  SPIN17  SPIN Total
# 0       1       0           5
# 1       1       2          33
# 2       4       2          31
# 3       0       0          11
# 4       3       0          13
#
# [5 rows x 44 columns]

# %% [markdown]
# ### **Cleaning Gaming.csv to only include Gaming Motivation and GAD scores**

# %%
#check columns for dropping
oggame_df.columns
# Out:
# Index(['Unnamed: 0', 'Entry', 'Gender', 'Age', 'Residence', 'Birthplace',
#        'Work', 'Degree', 'Game', 'Hours per Week', 'Gaming Motivation',
#        'Playstyle', 'GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6', 'GAD7',
#        'GAD Total', 'SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5', 'SWL Total',
#        'SPIN1', 'SPIN2', 'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6', 'SPIN7', 'SPIN8',
#        'SPIN9', 'SPIN10', 'SPIN11', 'SPIN12', 'SPIN13', 'SPIN14', 'SPIN15',
#        'SPIN16', 'SPIN17', 'SPIN Total'],
#       dtype='object')

# %%
#drop unused columns
dropoggame_df = oggame_df.drop(columns= ['Unnamed: 0', 'Gender', 'Age', 'Residence', 'Birthplace',
       'Work', 'Degree', 'Game', 'Hours per Week', 'Playstyle', 'SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5', 'SWL Total',
       'SPIN1', 'SPIN2', 'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6', 'SPIN7', 'SPIN8',
       'SPIN9', 'SPIN10', 'SPIN11', 'SPIN12', 'SPIN13', 'SPIN14', 'SPIN15',
       'SPIN16', 'SPIN17', 'SPIN Total'])

dropoggame_df
# Out:
#        Entry Gaming Motivation  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0          1        having fun     0     0     0     0     1     0     0
# 1          2        having fun     1     2     2     2     0     1     0
# 2          3        having fun     0     2     2     0     0     3     1
# 3          4         improving     0     0     0     0     0     0     0
# 4          5        having fun     2     1     2     2     2     3     2
# ...      ...               ...   ...   ...   ...   ...   ...   ...   ...
# 11133  14246         improving     1     0     0     1     0     1     1
# 11134  14247           winning     3     3     3     3     2     3     3
# 11135  14248        having fun     0     0     0     0     0     0     0
# 11136  14249        having fun     3     2     1     3     0     1     3
# 11137  14250         improving     1     1     0     0     0     0     0
#
#        GAD Total
# 0              1
# 1              8
# 2              8
# 3              0
# 4             14
# ...          ...
# 11133          4
# 11134         20
# 11135          0
# 11136         13
# 11137          2
#
# [11138 rows x 10 columns]

# %%
#looking at all dataframe responses
all_gm_responses = dropoggame_df['Gaming Motivation'].unique()
all_gm_responses
# Out:
# array(['having fun', 'improving', 'relaxing', 'winning',
#        'improving, having fun', 'All',
#        "I play it as I watch TV or movies.  I've gone through many a Netflix binge with Isaac.",
#        'all of the above', 'passing the time', 'having fun and improving',
#        'Forgetting troubles', 'All of them', 'Being with friends',
#        'getting good loot', 'have fun and win', 'Wasting time',
#        'talking to irl friends', 'improving while having fun',
#        'All of the above!', 'socializing', 'all above', 'playing well',
#        'the three last: improving, relaxing and having fun',
#        'winning and improving',
#        'depends, wwinning in rankeds, fun and relaxing in normal / aram',
#        'winning whilst improving', 'Relaxing & having fun',
#        'improving & having fun', 'All of the above.', 'All of the above',
#        'winning because if i lose while boosting i wont get money ',
#        'passing time', 'not thinking about my clinic depression.',
#        'all answers mentioned', 'All of the above ',
#        'Winning is the most fun but I sometimes still have fun if I loose',
#        'fulfilling a concept that you created based on the resources that are given to you by the game',
#        'conpeting, the fun that comes with it', 'mental stimulation',
#        'All of these 4', 'Not beeing bored',
#        'spending time with special person', 'relaxing+having fun',
#        'Improving and having fun',
#        "Distracting myself from the multiple disorders I have on bad days while on good days I don't play as much.",
#        "winning and improving, it's stoped being about fun a long time ago, but fun is still there",
#        'Equally value winning and having fun',
#        'all of the above minus relaxing', 'a good challenge',
#        'combination of all above, mostly improving and winning',
#        'both, improving and having fun', 'having fun while winning',
#        'winning while having fun', 'Depends on the day',
#        'All of those are goals and their importance varies.',
#        'Improving and relaxing too', 'Winning is funner',
#        'Winning AND Improving', 'destroying the enemy',
#        'First two options', 'haivng fun and winning equally important',
#        'A little bit of both to be honest. I play because its fun, but I prefer winning over losing obviously.',
#        'depends on my mood. sometimes winning and improving, sometimes just to relax',
#        'both relaxing and having fun', 'Being better than my friends',
#        'I mostly play out of habit.', 'forgetting',
#        'Working together for an objective, stopping people abusing each others',
#        'Performing', 'With friends having fun, alone improving',
#        'Improving and Having fun', 'Winning and having fun ',
#        'playing with friends',
#        'all of those, but i guess everyone wants to win...',
#        'The last 3 Choices', 'having fun=winning',
#        'Winning/Improving/Having Fun',
#        "winning is having fun. I can't choose between the two.",
#        'Working as a team', 'both improving and relaxing',
#        "All are important, I can only have fun and relax if I'm trying my best to win and improve",
#        'improving AND relaxing', 'having fun, winning and also improving',
#        'all of the above ', 'Both winning and having fun', 'Habit',
#        'Relaxing without improving or the other way rounds is a waste for me, so both.',
#        'A combination of fun (with friends,) and improving (in competitive)',
#        'not having retarded teammates',
#        'just wasting time as i have nothing else to do in life',
#        'Having fun and Improving', 'competeing',
#        'Haveing fun and relaxing', 'all the above',
#        'its a little of everything listed', 'metting new people',
#        'distraction', 'Distraction', 'killing time', 'satisfaction',
#        'Improving/ Having fun equal', 'time with friends',
#        'Having fun, expecially when winning', 'I have no idea',
#        'depends what im playing.',
#        'Both improving and having fun are equally important to me.',
#        'it just works as a distraction. other then that winning and climbing that ladder',
#        'Improving, having fun & winning', 'to be occupied',
#        'Improving + Fun', 'improving and having fun',
#        'Combination: Winning / Having fun', 'Having fun and improving',
#        'Making my brain go numb', 'All of above',
#        'Improving, relaxing and having fun are equally important to me and tied so close, that they cannot exist without each other (e.g. I can only have fun while relaxing and I always try to improve while relaxing and having fun),',
#        'occupation', 'Not feeling the pain my mind can inflict on me',
#        'i have fun when i see myself getting better at the game',
#        'Winning while having fun', 'Both having fun and improving.',
#        'All of the above with an emphasis on winning.',
#        'individual performance and winning together',
#        'Improving while having fun', 'dumpster the enemy beyond words',
#        'competitive play, improving but in games that are winnable',
#        "Winning and having fun, I'm a sporty person so I'm competitive.",
#        'Winning improving relaxing having fun',
#        'Getting to the top of the boards', 'winning/having fun',
#        'Having fun and improving 50/50', 'having fun with friends',
#        'improving, relaxing, and having fun.',
#        'Combination of having fun, relaxing and improving',
#        'playing the game',
#        'learning how the game works and compare to other games',
#        'both winning and improving, one brings the other',
#        'All of them, winning is fun, improving is rewarding.',
#        'depends on the match type. but having fun and improving means alot ',
#        'winning is fun but can have fun games without winning',
#        'Performing well', 'cooperating', 'Little of everything.',
#        'Depends on the mindset. Who am I playing with? It might be winning if I feel like being competitive, or just having fun.',
#        'improving + having fun', 'mix between winning and improving ',
#        'A mix of everything listed', 'forgetting about the reality',
#        'Killing time.', 'Teamwork',
#        "A combination of winning, improving, and having fun.  I don't regret playing if we don't win or make mistakes.",
#        'A mix of the 4 above', 'sometimes winning; sometimes having fun',
#        'All, depends on mood', 'winning, improving and having fun',
#        'having fun, but winning is fun',
#        'all of the above. I play league to relax and destress, but also to improve as I enter tournaments from time to time :)',
#        'Stimulate Cognition and logic thinking, relax/have fun',
#        "All of the above - losing isn't fun, but you can still learn to improve",
#        'Getting better at the game.', 'to pass time',
#        'Any of the former depending on the day.', 'competition',
#        'Crushing kids ', 'Having fun together WITH friends',
#        'in ranked, winning, in normal draft improving, in normal blind having fun',
#        'All of them :)', 'All of the above when playing LoL',
#        'all of above', 'having fun<improving<winning<relaxing',
#        'winning+improving',
#        'All of the above, alternating based on mood.',
#        'A mix of the last three',
#        'both improving and having fun equally important',
#        'Winning and having fun',
#        "It depends whether I'm playing ranked (improving/winning) or normals (having fun/relaxing)",
#        'a mixture of improving, relaxing, and having fun',
#        'fun is winning, so winning', 'Winning and improving. Both.',
#        'Having fun, but to enjoy competetive games you must be good. Therefore improving as well. ',
#        'content way to waste time',
#        'Doing well (not bringing my team down)', 'All of them really',
#        'having fun and then winning', 'winning and relaxing',
#        'Time with friends', 'Sexual thrill',
#        'having fun by giving it your best shot.',
#        'All but relaxing, but mostly fun', 'having fun by improving',
#        'Improving and having fun.', 'metagame',
#        'Mix of improving and having fun. ',
#        'Improving but also having fun :)',
#        'chasing singed and killing Teemo',
#        'learning, having fun and relaxing',
#        'hide from my real world problems', 'Escaping',
#        "I Have no idea why I'm playing.", 'trying to get my mind off',
#        'depends from Time to time ( between winning, improving, and having fun)',
#        'All of the above. Winning, improving, relaxing, and having fun.',
#        'helping others', 'a combination of all', 'A, B, and D',
#        'Learning', 'time sink (just something to do)',
#        'They all contribute equally',
#        'Improving/Having Fun/Teaching others', 'A mix of everything',
#        'improving when playing alone, having fun with friends',
#        'Winning, Improving, and having fun', 'having something to do',
#        'All the above', "Feeling like I'm playing my role well",
#        'getting away from real life', 'Winning AND having fun!',
#        'winning and having interesting plays',
#        'depends on game mode (ranked obviously winning, else for fun)',
#        'Improving, having fun and relaxing. ', 'backdooring in ARAMs',
#        'Keeping my mind off my shortcomings.',
#        'Improvement and enjoyment',
#        'having fun in some and winning in some ', 'Winning or having fun',
#        'all of the above, depending on the days',
#        "I'm competetive minded - improving/winning ", 'all of them',
#        'Improving + Having fun',
#        'improving mostly, but having fun as well', 'play with friends',
#        'Well.. Relaxing and having fun but also improving :D',
#        'Feeling that I performed well', 'a mix of all 4 points',
#        'depends, if playing with friends having fun otherways winning',
#        'Winning and Having Fun', 'Winning and improving',
#        'depending of mood, mostly winning, but sometimes I want to relax and have fun and I always want to improve',
#        'A mix of having fun and improving', 'Taking focus off of work',
#        'loot', 'relaxing and having fun',
#        'winning/improving/and having fun',
#        'mix between having fun and improving',
#        'playing with friends and winning with them as a team',
#        'winning and fun evenly',
#        'A mix between fun, improviment and winning',
#        'Challenging my brain and having fun while improving',
#        'Making it my living',
#        'Playing my best and having competent teammates',
#        'Both winning and improving quite equally',
#        'It varies, i like a mix of all. ', 'Having a new experience',
#        'fun doing my best and wining isnt bad',
#        "If it's not fun, I won't do it, however I want to get good at League because it can be challenging to get good at, it's something to work on in life and it's extremely fun so why the fuck not!",
#        'based on which gamemode. If ranked then winning and improving. If with friends then having fun.',
#        'improving means winning means having fun', 'The 4 of them',
#        'Improving, having fun, and teaching my friends',
#        'not arguing, focusing on gameplay',
#        'all of the above are equally important', 'competing',
#        'Winning with friends, winning while alone is almost depressing.',
#        'All equally important  ',
#        'Improving & having fun are equally important to me.',
#        'winning, while having fun', 'Learning the game',
#        'winning while improving', 'Learning/Strategizing',
#        'Passing time/Distracting myself from worrying',
#        'improving / tryin to relax',
#        'Multiplayer: winning. Single player: fun/ experiencing a great story',
#        'not losing my time and improve',
#        'Winning and improving at the same time', 'win and improve',
#        'Having fun by spending time with my friends :D',
#        'winning AND improving', 'winning/having fun/relaxing',
#        "If I'm playing with friends, it's about having fun. If I'm playing by myself, its about relaxing.",
#        'all together', 'doing something', 'overcoming boredom',
#        'a b c and d',
#        'improving AND winning are equally important to be honest. so...',
#        'having fun and improving are equalimy important tho',
#        'distracting myself', 'all of the above on different days',
#        'because im not able to check 2, Improving and having fun.',
#        'the other team losing', 'Playing well ',
#        'improving OR having fun depending on friend group',
#        'combination of having fun and wining', 'Playing the game',
#        'Winning while having fun his by far the best thing',
#        'winning, improving AND having fun', 'Both improving and relaxing',
#        'Improving & Winning', 'Escaping reality', 'Winning/improving ',
#        'winning helps with fun',
#        'I play to win while still trying to have fun and not let losing bother me. Improving is probably what I look forward to most, as the skill gap is enormous.',
#        'getting better so i can win more ', 'Having fun and Improving (:',
#        'The people I play with, the game is less important',
#        'All of The Above', 'some kind of improving and having fun',
#        "Making me forget about stuff that's making me nervous",
#        'releasing stress/tension', 'playing good',
#        'All four depending on the nature of the game (ranked, normals, aram, etc)',
#        'All the options are equally important',
#        'Winning and improving - equally',
#        'Winning and improving, i have fun when succeeding and i have learned to value losing.',
#        'Improving AND having fun, while trying to not get stressed.',
#        'Mental priority is Fun>Improve>Win, actual priority once in game Win>Improve>Fun'],
#       dtype=object)

# %%
#making all responses lowercase for uniformity and easier filtering
dropoggame_df['Gaming Motivation'] = dropoggame_df['Gaming Motivation'].str.lower()

#looking at all gaming motivation responses for cleanup + their counts
all_gm_response_counts = dropoggame_df['Gaming Motivation'].value_counts()
all_gm_response_counts
# Out:
# Gaming Motivation
# having fun                                                                          4479
# improving                                                                           4019
# winning                                                                             1699
# relaxing                                                                             566
# all of the above                                                                      36
#                                                                                     ...
# competitive play, improving but in games that are winnable                             1
# winning and having fun, i'm a sporty person so i'm competitive.                        1
# winning improving relaxing having fun                                                  1
# getting to the top of the boards                                                       1
# mental priority is fun>improve>win, actual priority once in game win>improve>fun       1
# Name: count, Length: 293, dtype: int64

# %%
#filtering dataframe 'Gaming Motivation' based on whether the string includes one of the words in keep_words
keep_words = ['win', 'improv', 'fun', 'relax', 'all', 'comb', 'mix']
filter_df = dropoggame_df[dropoggame_df['Gaming Motivation'].str.contains('|'.join(keep_words))]

#checking filtered dataframe's unique responses
filter_gm_response = filter_df['Gaming Motivation'].unique()
filter_gm_response
# Out:
# array(['having fun', 'improving', 'relaxing', 'winning',
#        'improving, having fun', 'all', 'all of the above',
#        'having fun and improving', 'all of them', 'have fun and win',
#        'improving while having fun', 'all of the above!', 'all above',
#        'the three last: improving, relaxing and having fun',
#        'winning and improving',
#        'depends, wwinning in rankeds, fun and relaxing in normal / aram',
#        'winning whilst improving', 'relaxing & having fun',
#        'improving & having fun', 'all of the above.',
#        'winning because if i lose while boosting i wont get money ',
#        'all answers mentioned', 'all of the above ',
#        'winning is the most fun but i sometimes still have fun if i loose',
#        'conpeting, the fun that comes with it', 'all of these 4',
#        'relaxing+having fun', 'improving and having fun',
#        "winning and improving, it's stoped being about fun a long time ago, but fun is still there",
#        'equally value winning and having fun',
#        'all of the above minus relaxing', 'a good challenge',
#        'combination of all above, mostly improving and winning',
#        'both, improving and having fun', 'having fun while winning',
#        'winning while having fun',
#        'all of those are goals and their importance varies.',
#        'improving and relaxing too', 'winning is funner',
#        'haivng fun and winning equally important',
#        'a little bit of both to be honest. i play because its fun, but i prefer winning over losing obviously.',
#        'depends on my mood. sometimes winning and improving, sometimes just to relax',
#        'both relaxing and having fun',
#        'with friends having fun, alone improving',
#        'winning and having fun ',
#        'all of those, but i guess everyone wants to win...',
#        'having fun=winning', 'winning/improving/having fun',
#        "winning is having fun. i can't choose between the two.",
#        'both improving and relaxing',
#        "all are important, i can only have fun and relax if i'm trying my best to win and improve",
#        'improving and relaxing', 'having fun, winning and also improving',
#        'both winning and having fun',
#        'relaxing without improving or the other way rounds is a waste for me, so both.',
#        'a combination of fun (with friends,) and improving (in competitive)',
#        'haveing fun and relaxing', 'all the above',
#        'improving/ having fun equal',
#        'having fun, expecially when winning',
#        'both improving and having fun are equally important to me.',
#        'it just works as a distraction. other then that winning and climbing that ladder',
#        'improving, having fun & winning', 'improving + fun',
#        'combination: winning / having fun', 'all of above',
#        'improving, relaxing and having fun are equally important to me and tied so close, that they cannot exist without each other (e.g. i can only have fun while relaxing and i always try to improve while relaxing and having fun),',
#        'i have fun when i see myself getting better at the game',
#        'both having fun and improving.',
#        'all of the above with an emphasis on winning.',
#        'individual performance and winning together',
#        'competitive play, improving but in games that are winnable',
#        "winning and having fun, i'm a sporty person so i'm competitive.",
#        'winning improving relaxing having fun', 'winning/having fun',
#        'having fun and improving 50/50', 'having fun with friends',
#        'improving, relaxing, and having fun.',
#        'combination of having fun, relaxing and improving',
#        'both winning and improving, one brings the other',
#        'all of them, winning is fun, improving is rewarding.',
#        'depends on the match type. but having fun and improving means alot ',
#        'winning is fun but can have fun games without winning',
#        'depends on the mindset. who am i playing with? it might be winning if i feel like being competitive, or just having fun.',
#        'improving + having fun', 'mix between winning and improving ',
#        'a mix of everything listed',
#        "a combination of winning, improving, and having fun.  i don't regret playing if we don't win or make mistakes.",
#        'a mix of the 4 above', 'sometimes winning; sometimes having fun',
#        'all, depends on mood', 'winning, improving and having fun',
#        'having fun, but winning is fun',
#        'all of the above. i play league to relax and destress, but also to improve as i enter tournaments from time to time :)',
#        'stimulate cognition and logic thinking, relax/have fun',
#        "all of the above - losing isn't fun, but you can still learn to improve",
#        'having fun together with friends',
#        'in ranked, winning, in normal draft improving, in normal blind having fun',
#        'all of them :)', 'all of the above when playing lol',
#        'having fun<improving<winning<relaxing', 'winning+improving',
#        'all of the above, alternating based on mood.',
#        'a mix of the last three',
#        'both improving and having fun equally important',
#        'winning and having fun',
#        "it depends whether i'm playing ranked (improving/winning) or normals (having fun/relaxing)",
#        'a mixture of improving, relaxing, and having fun',
#        'fun is winning, so winning', 'winning and improving. both.',
#        'having fun, but to enjoy competetive games you must be good. therefore improving as well. ',
#        'all of them really', 'having fun and then winning',
#        'winning and relaxing', 'having fun by giving it your best shot.',
#        'all but relaxing, but mostly fun', 'having fun by improving',
#        'improving and having fun.', 'mix of improving and having fun. ',
#        'improving but also having fun :)',
#        'learning, having fun and relaxing',
#        'depends from time to time ( between winning, improving, and having fun)',
#        'all of the above. winning, improving, relaxing, and having fun.',
#        'a combination of all', 'they all contribute equally',
#        'improving/having fun/teaching others', 'a mix of everything',
#        'improving when playing alone, having fun with friends',
#        'winning, improving, and having fun', 'winning and having fun!',
#        'winning and having interesting plays',
#        'depends on game mode (ranked obviously winning, else for fun)',
#        'improving, having fun and relaxing. ',
#        'improvement and enjoyment',
#        'having fun in some and winning in some ', 'winning or having fun',
#        'all of the above, depending on the days',
#        "i'm competetive minded - improving/winning ",
#        'improving mostly, but having fun as well',
#        'well.. relaxing and having fun but also improving :d',
#        'a mix of all 4 points',
#        'depends, if playing with friends having fun otherways winning',
#        'depending of mood, mostly winning, but sometimes i want to relax and have fun and i always want to improve',
#        'a mix of having fun and improving', 'relaxing and having fun',
#        'winning/improving/and having fun',
#        'mix between having fun and improving',
#        'playing with friends and winning with them as a team',
#        'winning and fun evenly',
#        'a mix between fun, improviment and winning',
#        'challenging my brain and having fun while improving',
#        'both winning and improving quite equally',
#        'it varies, i like a mix of all. ',
#        'fun doing my best and wining isnt bad',
#        "if it's not fun, i won't do it, however i want to get good at league because it can be challenging to get good at, it's something to work on in life and it's extremely fun so why the fuck not!",
#        'based on which gamemode. if ranked then winning and improving. if with friends then having fun.',
#        'improving means winning means having fun',
#        'improving, having fun, and teaching my friends',
#        'all of the above are equally important',
#        'winning with friends, winning while alone is almost depressing.',
#        'all equally important  ',
#        'improving & having fun are equally important to me.',
#        'winning, while having fun', 'winning while improving',
#        'improving / tryin to relax',
#        'multiplayer: winning. single player: fun/ experiencing a great story',
#        'not losing my time and improve',
#        'winning and improving at the same time', 'win and improve',
#        'having fun by spending time with my friends :d',
#        'winning/having fun/relaxing',
#        "if i'm playing with friends, it's about having fun. if i'm playing by myself, its about relaxing.",
#        'all together',
#        'improving and winning are equally important to be honest. so...',
#        'having fun and improving are equalimy important tho',
#        'all of the above on different days',
#        'because im not able to check 2, improving and having fun.',
#        'improving or having fun depending on friend group',
#        'combination of having fun and wining',
#        'winning while having fun his by far the best thing',
#        'improving & winning', 'winning/improving ',
#        'winning helps with fun',
#        'i play to win while still trying to have fun and not let losing bother me. improving is probably what i look forward to most, as the skill gap is enormous.',
#        'getting better so i can win more ', 'having fun and improving (:',
#        'some kind of improving and having fun',
#        'all four depending on the nature of the game (ranked, normals, aram, etc)',
#        'all the options are equally important',
#        'winning and improving - equally',
#        'winning and improving, i have fun when succeeding and i have learned to value losing.',
#        'improving and having fun, while trying to not get stressed.',
#        'mental priority is fun>improve>win, actual priority once in game win>improve>fun'],
#       dtype=object)

# %%
#creating main gaming motivation dataframe with only four responses (winning, improving, having fun, relaxing)
#making df copy and listing words to keep for filtering
simple_copy = filter_df.copy()
filtering_words = ['win','improv','fun','relax']

#filtering df to include rows with only one of the specific words and not any others
simple_filter_df = simple_copy[simple_copy['Gaming Motivation'].apply(
    lambda x: sum(1 for word in filtering_words if f'{word}' in f'{x}') == 1)]

#checking simple_filter responses and getting value counts
simple_filter_responses = simple_filter_df['Gaming Motivation'].value_counts()
simple_filter_responses
# Out:
# Gaming Motivation
# having fun                                                                                                                                                                                          4479
# improving                                                                                                                                                                                           4019
# winning                                                                                                                                                                                             1699
# relaxing                                                                                                                                                                                             566
# having fun together with friends                                                                                                                                                                       1
# having fun by spending time with my friends :d                                                                                                                                                         1
# not losing my time and improve                                                                                                                                                                         1
# winning with friends, winning while alone is almost depressing.                                                                                                                                        1
# if it's not fun, i won't do it, however i want to get good at league because it can be challenging to get good at, it's something to work on in life and it's extremely fun so why the fuck not!       1
# playing with friends and winning with them as a team                                                                                                                                                   1
# improvement and enjoyment                                                                                                                                                                              1
# winning and having interesting plays                                                                                                                                                                   1
# having fun by giving it your best shot.                                                                                                                                                                1
# individual performance and winning together                                                                                                                                                            1
# having fun with friends                                                                                                                                                                                1
# all of the above with an emphasis on winning.                                                                                                                                                          1
# i have fun when i see myself getting better at the game                                                                                                                                                1
# it just works as a distraction. other then that winning and climbing that ladder                                                                                                                       1
# all of those, but i guess everyone wants to win...                                                                                                                                                     1
# all of the above minus relaxing                                                                                                                                                                        1
# conpeting, the fun that comes with it                                                                                                                                                                  1
# winning because if i lose while boosting i wont get money                                                                                                                                              1
# getting better so i can win more                                                                                                                                                                       1
# Name: count, dtype: int64

# %%
#replacing longer responses with simpler responses
replace_dict = {
        "not losing my time and improve": "improving",
        "having fun together with friends": "having fun",
        "having fun by spending time with my friends :d": "having fun",
        "if it's not fun, i won't do it, however i want to get good at league because it can be challenging to get good at, it's something to work on in life and it's extremely fun so why the fuck not!": "having fun",
        "having fun by giving it your best shot.": "having fun",
        "having fun with friends": "having fun",
        "conpeting, the fun that comes with it": "having fun",
        "winning with friends, winning while alone is almost depressing.": "winning",
        "playing with friends and winning with them as a team": "winning",
        "winning and having interesting plays": "winning",
        "individual performance and winning together": "winning",
        "it just works as a distraction. other then that winning and climbing that ladder": "winning",
        "winning because if i lose while boosting i wont get money": "winning"
    
}
simple_copy_df = simple_filter_df.copy()
simple_copy_df.replace(replace_dict, inplace=True, regex=True)

#checking simple_filter responses and getting value counts
simple_filter_responses = simple_copy_df['Gaming Motivation'].value_counts()
simple_filter_responses
# Out:
# Gaming Motivation
# having fun                                                 4485
# improving                                                  4020
# winning                                                    1704
# relaxing                                                    566
# winning                                                       1
# all of the above minus relaxing                               1
# all of those, but i guess everyone wants to win...            1
# i have fun when i see myself getting better at the game       1
# all of the above with an emphasis on winning.                 1
# improvement and enjoyment                                     1
# getting better so i can win more                              1
# Name: count, dtype: int64

# %%
#drop mixed responses from simple_copy_df
#list of responses to keep
keep_resp = ["having fun", "improving", "winning", "relaxing"]

#copy of df 
simcopy_df = simple_copy_df.copy()

#keeping only keep_resp in dataframe
simpler_copy_df = simcopy_df[simcopy_df['Gaming Motivation'].isin(keep_resp)]

#checking counts for each response
simpler_copy_df['Gaming Motivation'].value_counts()
# Out:
# Gaming Motivation
# having fun    4485
# improving     4020
# winning       1704
# relaxing       566
# Name: count, dtype: int64

# %%
#creating df with 'all' responses
#creating all and mixed gaming motivation dataframe 
mix_copy = filter_df.copy()
mix_ans = ['win','improv','fun', 'relax', 'all', 'mix', 'comb']

#filter rows with two or more words from mix_ans
mix_filter_df = mix_copy[mix_copy['Gaming Motivation'].apply(lambda x: ('all ' in x) or (sum(word in x for word in mix_ans) >= 2))]

#checking mix_filter responses
mix_filter_responses = mix_filter_df['Gaming Motivation'].unique()
mix_filter_responses
# Out:
# array(['improving, having fun', 'all of the above',
#        'having fun and improving', 'all of them', 'have fun and win',
#        'improving while having fun', 'all of the above!', 'all above',
#        'the three last: improving, relaxing and having fun',
#        'winning and improving',
#        'depends, wwinning in rankeds, fun and relaxing in normal / aram',
#        'winning whilst improving', 'relaxing & having fun',
#        'improving & having fun', 'all of the above.',
#        'all answers mentioned', 'all of the above ',
#        'winning is the most fun but i sometimes still have fun if i loose',
#        'all of these 4', 'relaxing+having fun',
#        'improving and having fun',
#        "winning and improving, it's stoped being about fun a long time ago, but fun is still there",
#        'equally value winning and having fun',
#        'all of the above minus relaxing',
#        'combination of all above, mostly improving and winning',
#        'both, improving and having fun', 'having fun while winning',
#        'winning while having fun',
#        'all of those are goals and their importance varies.',
#        'improving and relaxing too', 'winning is funner',
#        'haivng fun and winning equally important',
#        'a little bit of both to be honest. i play because its fun, but i prefer winning over losing obviously.',
#        'depends on my mood. sometimes winning and improving, sometimes just to relax',
#        'both relaxing and having fun',
#        'with friends having fun, alone improving',
#        'winning and having fun ',
#        'all of those, but i guess everyone wants to win...',
#        'having fun=winning', 'winning/improving/having fun',
#        "winning is having fun. i can't choose between the two.",
#        'both improving and relaxing',
#        "all are important, i can only have fun and relax if i'm trying my best to win and improve",
#        'improving and relaxing', 'having fun, winning and also improving',
#        'both winning and having fun',
#        'relaxing without improving or the other way rounds is a waste for me, so both.',
#        'a combination of fun (with friends,) and improving (in competitive)',
#        'haveing fun and relaxing', 'all the above',
#        'improving/ having fun equal',
#        'having fun, expecially when winning',
#        'both improving and having fun are equally important to me.',
#        'improving, having fun & winning', 'improving + fun',
#        'combination: winning / having fun', 'all of above',
#        'improving, relaxing and having fun are equally important to me and tied so close, that they cannot exist without each other (e.g. i can only have fun while relaxing and i always try to improve while relaxing and having fun),',
#        'both having fun and improving.',
#        'all of the above with an emphasis on winning.',
#        'competitive play, improving but in games that are winnable',
#        "winning and having fun, i'm a sporty person so i'm competitive.",
#        'winning improving relaxing having fun', 'winning/having fun',
#        'having fun and improving 50/50',
#        'improving, relaxing, and having fun.',
#        'combination of having fun, relaxing and improving',
#        'both winning and improving, one brings the other',
#        'all of them, winning is fun, improving is rewarding.',
#        'depends on the match type. but having fun and improving means alot ',
#        'winning is fun but can have fun games without winning',
#        'depends on the mindset. who am i playing with? it might be winning if i feel like being competitive, or just having fun.',
#        'improving + having fun', 'mix between winning and improving ',
#        "a combination of winning, improving, and having fun.  i don't regret playing if we don't win or make mistakes.",
#        'sometimes winning; sometimes having fun',
#        'winning, improving and having fun',
#        'having fun, but winning is fun',
#        'all of the above. i play league to relax and destress, but also to improve as i enter tournaments from time to time :)',
#        'stimulate cognition and logic thinking, relax/have fun',
#        "all of the above - losing isn't fun, but you can still learn to improve",
#        'in ranked, winning, in normal draft improving, in normal blind having fun',
#        'all of them :)', 'all of the above when playing lol',
#        'having fun<improving<winning<relaxing', 'winning+improving',
#        'all of the above, alternating based on mood.',
#        'both improving and having fun equally important',
#        'winning and having fun',
#        "it depends whether i'm playing ranked (improving/winning) or normals (having fun/relaxing)",
#        'a mixture of improving, relaxing, and having fun',
#        'fun is winning, so winning', 'winning and improving. both.',
#        'having fun, but to enjoy competetive games you must be good. therefore improving as well. ',
#        'all of them really', 'having fun and then winning',
#        'winning and relaxing', 'all but relaxing, but mostly fun',
#        'having fun by improving', 'improving and having fun.',
#        'mix of improving and having fun. ',
#        'improving but also having fun :)',
#        'learning, having fun and relaxing',
#        'depends from time to time ( between winning, improving, and having fun)',
#        'all of the above. winning, improving, relaxing, and having fun.',
#        'a combination of all', 'they all contribute equally',
#        'improving/having fun/teaching others',
#        'improving when playing alone, having fun with friends',
#        'winning, improving, and having fun', 'winning and having fun!',
#        'depends on game mode (ranked obviously winning, else for fun)',
#        'improving, having fun and relaxing. ',
#        'having fun in some and winning in some ', 'winning or having fun',
#        'all of the above, depending on the days',
#        "i'm competetive minded - improving/winning ",
#        'improving mostly, but having fun as well',
#        'well.. relaxing and having fun but also improving :d',
#        'a mix of all 4 points',
#        'depends, if playing with friends having fun otherways winning',
#        'depending of mood, mostly winning, but sometimes i want to relax and have fun and i always want to improve',
#        'a mix of having fun and improving', 'relaxing and having fun',
#        'winning/improving/and having fun',
#        'mix between having fun and improving', 'winning and fun evenly',
#        'a mix between fun, improviment and winning',
#        'challenging my brain and having fun while improving',
#        'both winning and improving quite equally',
#        'it varies, i like a mix of all. ',
#        'fun doing my best and wining isnt bad',
#        "if it's not fun, i won't do it, however i want to get good at league because it can be challenging to get good at, it's something to work on in life and it's extremely fun so why the fuck not!",
#        'based on which gamemode. if ranked then winning and improving. if with friends then having fun.',
#        'improving means winning means having fun',
#        'improving, having fun, and teaching my friends',
#        'all of the above are equally important',
#        'all equally important  ',
#        'improving & having fun are equally important to me.',
#        'winning, while having fun', 'winning while improving',
#        'improving / tryin to relax',
#        'multiplayer: winning. single player: fun/ experiencing a great story',
#        'winning and improving at the same time', 'win and improve',
#        'winning/having fun/relaxing',
#        "if i'm playing with friends, it's about having fun. if i'm playing by myself, its about relaxing.",
#        'all together',
#        'improving and winning are equally important to be honest. so...',
#        'having fun and improving are equalimy important tho',
#        'all of the above on different days',
#        'because im not able to check 2, improving and having fun.',
#        'improving or having fun depending on friend group',
#        'combination of having fun and wining',
#        'winning while having fun his by far the best thing',
#        'improving & winning', 'winning/improving ',
#        'winning helps with fun',
#        'i play to win while still trying to have fun and not let losing bother me. improving is probably what i look forward to most, as the skill gap is enormous.',
#        'having fun and improving (:',
#        'some kind of improving and having fun',
#        'all four depending on the nature of the game (ranked, normals, aram, etc)',
#        'all the options are equally important',
#        'winning and improving - equally',
#        'winning and improving, i have fun when succeeding and i have learned to value losing.',
#        'improving and having fun, while trying to not get stressed.',
#        'mental priority is fun>improve>win, actual priority once in game win>improve>fun'],
#       dtype=object)

# %%
#replacing all mixed filter responses with "mixed response"
mix_copy_df = mix_filter_df.copy()
mix_copy_df['Gaming Motivation'] = 'mixed response'

#concat mix_copy_df and simple_copy_df together
concat_GADgm = pd.concat([simpler_copy_df, mix_copy_df])
#checking counts for each response
concat_GADgm['Gaming Motivation'].value_counts()
# Out:
# Gaming Motivation
# having fun        4485
# improving         4020
# winning           1704
# relaxing           566
# mixed response     244
# Name: count, dtype: int64

# %%
#sorting GADgm by Entry number
sorted_GADgm = concat_GADgm.sort_values(by= 'Entry')

#capitalizing/renaming responses in Gaming Motivation
rename ={
    'having fun': 'Having Fun',
    'relaxing': 'Relaxing',
    'improving': 'Improving',
    'winning': 'Winning',
    'mixed response': 'Mixed Response'

}
GADgm_df = sorted_GADgm.copy()
GADgm_df.replace(rename, inplace=True, regex=True)

#checking GADgm responses
GADgm_responses = GADgm_df['Gaming Motivation'].value_counts()
GADgm_responses
# Out:
# Gaming Motivation
# Having Fun        4485
# Improving         4020
# Winning           1704
# Relaxing           566
# Mixed Response     244
# Name: count, dtype: int64

# %% [markdown]
# ### **Pie chart of gaming motivation categories**

# %%
#creating pie chart or bar graph of all responses used for question
resp_pie = GADgm_df["Gaming Motivation"].value_counts()
resp_pie_df = pd.DataFrame(resp_pie)
resp_pie_df.plot(kind="pie", 
    figsize=(10,10),
    autopct = "%1.1f%%", 
    title= "Gaming Motivation Response Number Comparison", 
    subplots = True, 
    ylabel = "Gaming Motivation", 
    colors = ["cornflowerblue", "lightpink", "aquamarine", "oldlace", "plum"])
plt.legend(loc="best", fontsize = "medium")
plt.tight_layout;

fold_path = "../images/"
plt.savefig(fold_path + 'GameMotive_Pie')

# %% [markdown]
# #### Pie-chart explanation:
# - This chart shows an overview of the population's responses to what their motivation is when gaming. The majority of the responses recorded consisted of "Having Fun" and "Improving"

# %% [markdown]
# ### **Boxplot displaying gaming motivation categories based on anxiety**

# %%
#creating boxplot for anxiety and gaming motivation
#list for for loop (and later for plot labels)
gaming_motive = ["Having Fun", "Relaxing", "Improving", "Winning", "Mixed Response"]
#creating new dataframe for data plotting with lists
entry_list = GADgm_df['Entry'].tolist()
gm_list = GADgm_df['Gaming Motivation'].tolist()
GADtotal_list = GADgm_df['GAD Total'].tolist()

plot_data_df = {
     'Entry' : entry_list,
     'Gaming Motivation' : gm_list,
     'GAD Total' : GADtotal_list
}

plot_data_df = pd.DataFrame(plot_data_df)

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for motive in gaming_motive:
    quartiles = plot_data_df.loc[plot_data_df['Gaming Motivation'] == motive, 'GAD Total'].quantile([0.25, 0.5, 0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq

    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)

    box_data = plot_data_df.loc[plot_data_df['Gaming Motivation'] == motive, 'GAD Total']
    outliers = box_data[(box_data < lower_bound) | (box_data > upper_bound)]

    #printing number of outliers and total responses for each gaming motivation
    print(f"The gaming motive '{motive}' has {outliers.count()} potential outlier(s) out of {len(box_data)} responses.")

#creating box plot for GAD Total vs Gaming Motivation
#setting figure size
fig, ax = plt.subplots(figsize=(7,6))

#setting box plot positions 
positions = range(1, len(gaming_motive) +1)

#plotting box plots for each gaming motive based on GAD Total
for i, motive in enumerate(gaming_motive):
    motive_data = plot_data_df[plot_data_df['Gaming Motivation'] == motive]['GAD Total']
    
    #formatting boxplots
    boxplot = ax.boxplot(motive_data,
                         positions=[positions[i]],
                         widths=0.4,
                         patch_artist=True,
                         boxprops=dict(facecolor='lightpink', alpha=0.5),
                         flierprops=dict(marker='o', markerfacecolor='lightpink', markersize=5))

#extra formatting for boxplots
ax.set_xticks(positions)
ax.set_xticklabels(gaming_motive)
ax.set_title('GAD Total Level vs Gaming Motivation')
ax.set_ylabel('GAD Total')
ax.set_xlabel('Gaming Motivation Responses')


plt.tight_layout()
fold_path = "../images/"
plt.savefig(fold_path + 'GameMotive_BoxPlot')
# Out:
# The gaming motive 'Having Fun' has 105 potential outlier(s) out of 4485 responses.
# The gaming motive 'Relaxing' has 10 potential outlier(s) out of 566 responses.
# The gaming motive 'Improving' has 208 potential outlier(s) out of 4020 responses.
# The gaming motive 'Winning' has 31 potential outlier(s) out of 1704 responses.
# The gaming motive 'Mixed Response' has 7 potential outlier(s) out of 244 responses.

# %% [markdown]
# #### Box-plot explanation:
# - The gaming motive 'Having Fun' has 105 potential outliers out of 4485 responses. 'Relaxing' has 10/566 potential outliers. 'Improving' has 208/4020,'Winning' has 31/1704, and 'Mixed Response' has 7/244. Looking at the output of GAD scores for each gaming motive, each gaming motive's full response length, and taking into consideration the cleaned dataset (I removed rows that I figured ingenuine due to their content and consisted of answers that did not align with the goal of this analysis) and the highest score possible for the GAD-7, I deemed the majority of these outliers to be genuine. However, it should be taken into account that based on our population (2015 online gamers/reddit users likely not within a strict survey environment) it is likely some responses may be disingenuine.

# %% [markdown]
# ### **Independent t-test of gaming motivation categories**

# %%
#creating independent t tests between different gaming motives and their GAD Totals
#creating separate populations for each gaming motive
fun_pop = []
improve_pop = []
relax_pop = []
win_pop = []
mix_pop = []

for index, row in plot_data_df.iterrows():
    if row['Gaming Motivation'] == 'Having Fun':
        fun_pop.append(row['GAD Total'])
    elif row['Gaming Motivation'] == 'Improving':
        improve_pop.append(row['GAD Total'])
    elif row['Gaming Motivation'] == 'Relaxing':
        relax_pop.append(row['GAD Total'])
    elif row['Gaming Motivation'] == 'Winning':
        win_pop.append(row['GAD Total'])
    elif row['Gaming Motivation'] == 'Mixed Response':
        mix_pop.append(row['GAD Total'])


#creating definition for creating independent-T test taking two different populations, their labels, and a figure title
def ttestdata(pop1, pop2, label1, label2, figtitle):
    #getting random sample from the previous populations
    sample_size = 244
    sample_pop1 = random.sample(pop1, sample_size)
    sample_pop2 = random.sample(pop2, sample_size)

    #making scatter plot of data
    plt.figure(figsize=(12, 8))
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(sample_pop1)), sample_pop1, label= label1, marker="o", color= 'cornflowerblue', edgecolor='navy', alpha = 0.7)
    plt.scatter(range(len(sample_pop2)), sample_pop2, label= label2, marker="o", color= 'lightpink', edgecolor='mediumvioletred', alpha = 0.7)
    plt.legend(loc = 'best')
    plt.title(f"{label1} GAD Total vs {label2} GAD Total")
    plt.savefig(f'{figtitle}_Scatter')

    #making histogram of data
    plt.figure(figsize=(12, 8))
    plt.subplot(2, 1, 2)
    plt.hist(sample_pop1, 10, density=True, alpha=0.7, label= label1, color = 'cornflowerblue', edgecolor='navy')
    plt.hist(sample_pop2, 10, density=True, alpha=0.7, label= label2, color = 'lightpink', edgecolor='mediumvioletred')
    plt.axvline(np.mean(sample_pop1), color='navy', linestyle='dashed', linewidth=1, alpha = 0.7)
    plt.axvline(np.mean(sample_pop2), color='mediumvioletred', linestyle='dashed', linewidth=1, alpha = 0.7)
    plt.legend(loc= 'best')
    plt.title(f"{label1} GAD Total vs {label2} GAD Total")
    plt.tight_layout
    fold_path = "../images/"
    plt.savefig(fold_path + f'{figtitle}_Histogram')

    #t-statistic, and p-value
    t_statistic, p_value = stats.ttest_ind(sample_pop1, sample_pop2, equal_var=False)

    #calculating degrees of freedom
    deg_freedom = len(pop1) + len(pop2) -2
    
    #structuring sentence output

    #determining words higher or lower based on t-statistic
    hi_lo = ""
    if (t_statistic < 0):
        hi_lo = "lower"
    else:
        hi_lo = "higher"

    #determining which sentence to output based on p-value and rounding results
    psig = ""
    
    if (p_value < 0.05):
        psig = f'Using an alpha level of 0.5, those that listed their gaming motivation as "{label1}" ' \
                f'had significantly {hi_lo} GAD totals than those listing theirs as "{label2}", ' \
                f't({round(deg_freedom, 0)}) = {round(t_statistic, 3)}, p = {round(p_value, 4)}.'
    else:
        psig = f'The relationship between {label1} and {label2} as gaming motivation was found to be not significant, t({round(deg_freedom, 0)}) = {round(t_statistic, 3)}, p = {round(p_value, 4)}.'

    
    print(psig)






ttestdata(fun_pop, win_pop, "Having Fun", "Winning", "FunWin")
# Out:
# Using an alpha level of 0.5, those that listed their gaming motivation as "Having Fun" had significantly lower GAD totals than those listing theirs as "Winning", t(6187) = -2.862, p = 0.0044.

# %%
#testing "relaxing" and "improving" to see where they stand in the histogram compared to "winning" and "having fun" graphs
ttestdata(improve_pop, relax_pop, "Improving", "Relaxing", "ImprovRelax")
# Out:
# Using an alpha level of 0.5, those that listed their gaming motivation as "Improving" had significantly lower GAD totals than those listing theirs as "Relaxing", t(4584) = -3.217, p = 0.0014.

# %% [markdown]
# #### Independent t-tests explanation/analysis:
# - I wanted to look into was whether or not playing games to win would have a difference in GAD scores in comparison to playing just to have fun. I found that when comparing the GAD totals for the two motivations, "Having Fun" had significantly lower GAD totals in comparison to those that listed their gaming motivation as "Winning". There were slight variations due to random sampling, but generally the *t*-statistic was less than -1 and the *p*-value was less than 0.05, (*t*(6187) = -2.596, *p* = 0.0097). Therefore, we reject the null hypothesis.
#  - I had a few sub-questions as well and ran a few more tests comparing winning and relaxing against the other categories because, I wanted to see if there was a spectrum of sorts between the categories associated with GAD scores. Most tests aligned with my hypothesis, such as "Having Fun" being associated with lower GAD scores such as when being compared to "Winning" (mentioned earlier) and "Improving" (*t*(8503) = -2.451, *p* = 0.0146). "Winning" also seemed to be associated with higher GAD scores when comparing it to "Having Fun" (as mentioned earlier) and "Improving" (*t*(5722) = 2.112, *p* = 0.0352). However, I found two significant tests concerning relaxation that I found interesting. Depending on the random sample chosen (the tests had been run multiple times) the gaming motivation "Relaxing" would significantly be associated with higher GAD scores when compared to "Improving" (*t*(4584) = -2.44, *p* = 0.0151) and "Having Fun" (*t*(5049) = -4.435, *p* = 0.00). Lastly, although the test between "Relaxing" and "Winning" had been not significant, I thought it was worth mentioning that even with the difference in original population sizes between the two categories ("Winning = 1704, "Relaxing" = 566), "Relaxing" had consistently shown a higher number of the highest GAD total. I had originally believed that "Relaxing" would be the lowest on the spectrum with the lowest GAD scores. But since that was not the case, this lead me to consider that many of the participants in the study that chose "Relaxing" as their gaming motive may have generally had a higher base GAD when compared to other motives, and that playing games may have been part of a form of relaxation for them.
#
#  ***the statistics used within this analysis applied to the time of testing and may not be the same when the code is run again

# %% [markdown]
# #### Conclusion:
# - Overall, multiple significant tests had been run and thus we reject the null hypothesis. "Winning" may be associated with higher GAD scores while "Having Fun" is associated with lower GAD scores. "Relaxing" is so far associated with scores nearing the "Winning" gaming motivation category and I believe this should be further tested. If the goal is to help alleviate the anxiety in participants in the long run, I believe looking into the various causes of higher totals concering the GAD-7 would be worthwhile. A larger sample size may be needed and it would also be worth looking into being able to test whether the base GAD totals for each gaming motivation category correspond to the GAD totals of the individuals themselves, or whether the games contribute to the GAD totals. There should also be further research into why the "Winning" category is associated with higher GAD scores- the types of people playing to win would be worth looking into. For example, whether they need to win games in order to make a living and this is why their anxiety is generally higher. Or, perhaps those with higher anxiety in general tend to focus on winning their games. There is also the question as to whether or not those with the "Having Fun" motive have less anxiety in general and thus a greater capacity to have fun while playing, or whether them having more fun while playing gives way to overall less anxiety in their daily lives.
